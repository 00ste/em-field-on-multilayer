# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('output.csv', header=None, delimiter=';')

# %%
interfaces = [0, 3.5e-3, 4.1e-3, 5.2e-3]

# %%
fig, axs = plt.subplots(2, 3)
plt.subplots_adjust(top=1.2, right=2.0)
axs[0][0].plot(data[1], data[2], 'bo')
axs[0][0].set_title('|Ex|')
axs[0][1].plot(data[1], data[4], 'bo')
axs[0][1].set_title('|Ey|')
axs[0][2].plot(data[1], data[6], 'bo')
axs[0][2].set_title('|Ez|')
axs[1][0].plot(data[1], data[3], 'bo')
axs[1][0].set_title('arg(Ex)')
axs[1][1].plot(data[1], data[5], 'bo')
axs[1][1].set_title('arg(Ey)')
axs[1][2].plot(data[1], data[7], 'bo')
axs[1][2].set_title('arg(Ez)')

for i in range(2):
    for j in range(3):
        for interface in interfaces:
            axs[i][j].axvline(x=interface, c='k')

# %%
fig, axs = plt.subplots(2, 3)
plt.subplots_adjust(top=1.2, right=2.0)
axs[0][0].plot(data[1], data[8], 'bo')
axs[0][0].set_title('|Hx|')
axs[0][1].plot(data[1], data[10], 'bo')
axs[0][1].set_title('|Hy|')
axs[0][2].plot(data[1], data[12], 'bo')
axs[0][2].set_title('|Hz|')
axs[1][0].plot(data[1], data[9], 'bo')
axs[1][0].set_title('arg(Hx)')
axs[1][1].plot(data[1], data[11], 'bo')
axs[1][1].set_title('arg(Hy)')
axs[1][2].plot(data[1], data[13], 'bo')
axs[1][2].set_title('arg(Hz)')

for i in range(2):
    for j in range(3):
        for interface in interfaces:
            axs[i][j].axvline(x=interface, c='k')

# %%
for z in np.linspace(-1.0e-3, -0.99e-3, 101):
    print(f'0, {z}')
# Out:
# 0, -0.001
# 0, -0.0009999
# 0, -0.0009998000000000001
# 0, -0.0009997
# 0, -0.0009996
# 0, -0.0009995
# 0, -0.0009994000000000001
# 0, -0.0009993
# 0, -0.0009992
# 0, -0.0009991
# 0, -0.000999
# 0, -0.0009989
# 0, -0.0009988
# 0, -0.0009987
# 0, -0.0009986
# 0, -0.0009985
# 0, -0.0009984
# 0, -0.0009983
# 0, -0.0009982
# 0, -0.0009981
# 0, -0.000998
# 0, -0.0009979
# 0, -0.0009978
# 0, -0.0009977
# 0, -0.0009976
# 0, -0.0009975000000000001
# 0, -0.0009974
# 0, -0.0009973
# 0, -0.0009972
# 0, -0.0009971000000000001
# 0, -0.000997
# 0, -0.0009969
# 0, -0.0009968
# 0, -0.0009967
# 0, -0.0009966
# 0, -0.0009965
# 0, -0.0009964
# 0, -0.0009963
# 0, -0.0009962
# 0, -0.0009961
# 0, -0.000996
# 0, -0.0009959
# 0, -0.0009958
# 0, -0.0009957
# 0, -0.0009956
# 0, -0.0009955
# 0, -0.0009954
# 0, -0.0009953
# 0, -0.0009952
# 0, -0.0009951
# 0, -0.000995
# 0, -0.0009949
# 0, -0.0009948000000000001
# 0, -0.0009947
# 0, -0.0009946
# 0, -0.0009945
# 0, -0.0009944
# 0, -0.0009943
# 0, -0.0009942
# 0, -0.0009941
# 0, -0.000994
# 0, -0.0009939
# 0, -0.0009938
# 0, -0.0009937
# 0, -0.0009936
# 0, -0.0009935
# 0, -0.0009934
# 0, -0.0009933
# 0, -0.0009932
# 0, -0.0009931
# 0, -0.000993
# 0, -0.0009929
# 0, -0.0009928
# 0, -0.0009927
# 0, -0.0009926
# 0, -0.0009925
# 0, -0.0009924
# 0, -0.0009923
# 0, -0.0009922
# 0, -0.0009921
# 0, -0.000992
# 0, -0.0009919
# 0, -0.0009918
# 0, -0.0009917
# 0, -0.0009916
# 0, -0.0009915
# 0, -0.0009914
# 0, -0.0009913
# 0, -0.0009912
# 0, -0.0009911
# 0, -0.000991
# 0, -0.0009909
# 0, -0.0009908
# 0, -0.0009907
# 0, -0.0009906
# 0, -0.0009905
# 0, -0.0009904
# 0, -0.0009903
# 0, -0.0009901999999999999
# 0, -0.0009901
# 0, -0.00099
